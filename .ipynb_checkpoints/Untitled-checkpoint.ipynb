# %% [markdown]
# # **Importing Libraries**

# %%
import os
import numpy as np
import pandas as pd
from sklearn import svm
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.model_selection import train_test_split    
import time
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_30184/1100323845.py in <module>
#       5 from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
#       6 from sklearn.model_selection import train_test_split
# ----> 7 import timeª
#
# ModuleNotFoundError: No module named 'timea'

# %% [markdown]
# # **Reading csv file**

# %%
filePath = os.path.join(os.getcwd(), 'archive', 'BCCC-CIRA-CIC-DoHBrw-2020.csv')
df = pd.read_csv(filePath, delimiter=',', header=0)
df.head(10)
# Out:
#    FlowBytesSent  FlowSentRate  FlowBytesReceived  FlowReceivedRate  \
# 0            353  8.089035e+01                393         90.056393
# 1           1807  5.305671e+01               4828        141.758602
# 2          15000  4.795360e+02              27719        886.150575
# 3           1755  5.819307e+01               4617        153.125406
# 4            618  3.491495e+00                315          1.779646
# 5           1739  5.100614e+01               4759        139.584944
# 6           1807  5.306261e+01               4828        141.774379
# 7           1032  5.739392e+03               3635      20215.783327
# 8             94  1.685367e+06                 55     992895.241749
# 9         492362  4.575001e+03             279967       2601.438029
#
#    PacketLengthVariance  PacketLengthStandardDeviation  PacketLengthMean  \
# 0            469.209877                      21.661253         82.888889
# 1         145520.370987                     381.471324        228.793103
# 2          25949.480963                     161.088426        135.186709
# 3         154088.445853                     392.541007        245.112953
# 4            319.410000                      17.872045         93.300000
# 5         322000.222222                     567.450634        240.666667
# 6         145520.370987                     381.471324        228.793103
# 7         270099.964844                     519.711425        291.687500
# 8            380.250000                      19.500000         75.477101
# 9          17062.269943                     130.622624        233.755751
#
#    PacketLengthMedian  PacketLengthMode  PacketLengthSkewFromMedian  ...  \
# 0           66.000000                66                    2.339046  ...
# 1           76.000000                68                    1.201609  ...
# 2           87.000000                87                    0.897396  ...
# 3           75.500000                54                    1.296268  ...
# 4          105.000000               105                   -1.963961  ...
# 5           76.000000                68                    0.870560  ...
# 6           76.000000                68                    1.201609  ...
# 7           72.000000                68                    1.268132  ...
# 8           75.477101                55                    0.000000  ...
# 9          259.000000                68                   -0.579783  ...
#
#    PacketTimeCoefficientofVariation  ResponseTimeTimeVariance  \
# 0                          0.534524              1.754601e-09
# 1                          1.591559              5.348911e-05
# 2                          0.670950              3.356292e-01
# 3                          2.029971              1.245935e+02
# 4                          0.816362              2.975575e-09
# 5                          1.513294              4.524418e-05
# 6                          1.592916              6.386221e-05
# 7                          0.611148              1.484102e-04
# 8                          1.000000              0.000000e+00
# 9                          0.565079              3.379076e-05
#
#    ResponseTimeTimeStandardDeviation  ResponseTimeTimeMean  \
# 0                           0.000042              0.000048
# 1                           0.007314              0.011523
# 2                           0.579335              0.139518
# 3                          11.162146              5.011613
# 4                           0.000054              0.015507
# 5                           0.006726              0.011740
# 6                           0.007991              0.011117
# 7                           0.012182              0.014927
# 8                           0.000000              0.000056
# 9                           0.005813              0.002318
#
#    ResponseTimeTimeMedian  ResponseTimeTimeMode  \
# 0                0.000019              0.000017
# 1                0.015273              0.000016
# 2                0.001976              0.000003
# 3                0.015778              0.012884
# 4                0.015471              0.015466
# 5                0.015220              0.000084
# 6                0.015458              0.000027
# 7                0.024394              0.000010
# 8                0.000056              0.000056
# 9                0.000435              0.000421
#
#    ResponseTimeTimeSkewFromMedian  ResponseTimeTimeSkewFromMode  \
# 0                        2.028699                      0.737490
# 1                       -1.538407                      1.573304
# 2                        0.712241                      0.240819
# 3                        1.342708                      0.447829
# 4                        1.986391                      0.751146
# 5                       -1.552321                      1.732879
# 6                       -1.629463                      1.387800
# 7                       -2.331221                      1.224507
# 8                      -10.000000                    -10.000000
# 9                        0.972029                      0.326418
#
#    ResponseTimeTimeCoefficientofVariation      Label
# 0                                0.869641     Benign
# 1                                0.634722  Malicious
# 2                                4.152404  Malicious
# 3                                2.227258     Benign
# 4                                0.003502     Benign
# 5                                0.572945  Malicious
# 6                                0.718815  Malicious
# 7                                0.816108  Malicious
# 8                                0.000000     Benign
# 9                                2.507257  Malicious
#
# [10 rows x 29 columns]
